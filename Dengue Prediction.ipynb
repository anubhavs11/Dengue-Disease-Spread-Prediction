# %%
import pandas as pd

# %%
train = pd.read_csv("dataset/dengue_features_train.csv")
train.head()
# Out:
#     ndvi_ne   ndvi_nw   ndvi_se   ndvi_sw  precipitation_amt_mm  \
# 0  0.122600  0.103725  0.198483  0.177617                 12.42
# 1  0.169900  0.142175  0.162357  0.155486                 22.82
# 2  0.032250  0.172967  0.157200  0.170843                 34.54
# 3  0.128633  0.245067  0.227557  0.235886                 15.36
# 4  0.196200  0.262200  0.251200  0.247340                  7.52
#
#    reanalysis_air_temp_k  reanalysis_avg_temp_k  reanalysis_dew_point_temp_k  \
# 0             297.572857             297.742857                   292.414286
# 1             298.211429             298.442857                   293.951429
# 2             298.781429             298.878571                   295.434286
# 3             298.987143             299.228571                   295.310000
# 4             299.518571             299.664286                   295.821429
#
#    reanalysis_max_air_temp_k  reanalysis_min_air_temp_k     ...       \
# ...

# %%
def computeCost(X,y,theta):
    n=len(X[0]);
    m=len(X);
    
    h = [0]*m
    
    for i in range(m):
        for j in range(n):
            h[i] += X[i][j]*theta[j]
    sum=0
    for i in range(m):
        sum+=h[i]-y[i]
        
    J = 1/(2*m) *sum
    return J

# %%
X = [[1,2],[3,4]]
theta = [2,4]
y = [1,1]
J = computeCost(X,y,theta)

# %%
J
# Out:
# 7.5

# %%
def gradientDescent(X,y,theta,num_iter,alpha):
    m = len(y)
    n = len(X[0])
    temp_theta = theta
    
    J_history = [10000000]*num_iter
    
    for k in range(num_iter):
        
        h = [0]*m
        
        for i in range(m):
            for j in range(n):
                h[i] += X[i][j]*theta[j]
        # End of loop
        diff = y
        for i in range(m):
            diff[i] = h[i]-y[i]
        
        X_temp = X
        sum = [0]*m
        for i in range(m):
            for j in range(n):
                X_temp[i][j] = diff[i]*X[i][j]
                sum[i] = sum[i] + X_temp[i][j]
                
        for i in range(m):
            temp_theta[i] = theta[i] - alpha*(1/m)*sum[i]
        
        theta = temp_theta
        
        J_history[i] = computeCost(X,y,theta)
    return J_history

# %%
X = [[1,2],[3,4]]
theta = [2,4]
y = [1,1]
num_iter = 10
alpha = 1
#J_history = gradientDescent(X,y,theta,num_iter,alpha)

m = len(y)
n = len(X[0])

J_history = [10000000]*num_iter

for k in range(num_iter):

    h = [0]*m

    for i in range(m):
        for j in range(n):
            h[i] += X[i][j]*theta[j]
    # End of loop
    diff = [0]*m
    
    for i in range(m):
        diff[i] = h[i]-y[i]
    
    X_temp = [[0]*n]*m
    sum = [0]*m
    for i in range(m):
        for j in range(n):
            X_temp[i][j] = diff[i]*X[i][j]
            sum[i] = sum[i] + X_temp[i][j]

    for i in range(m):
        theta[i] = theta[i] - alpha*(1/m)*sum[i]
 
    #print(computeCost(X,y,theta))
    print(theta)
    J_history[i] = computeCost(X,y,theta)
# Out:
# [-11.5, -69.5]
# [215.75, 1027.75]
# [-3189.625, -15622.625]
# [48464.1875, 236588.6875]
# [-733996.65625, -3584523.40625]
# [11120570.046875, 54305772.671875]
# [-168477601.5390625, -822741026.7265625]
# [2552461882.4492188, 12464648167.105469]
# [-38670175441.041016, -188841275934.5879]
# [585858915525.7842, 2860973429284.073]

# %%
J_history
# Out:
# [10000000,
#  4877319059451.394,
#  10000000,
#  10000000,
#  10000000,
#  10000000,
#  10000000,
#  10000000,
#  10000000,
#  10000000]
